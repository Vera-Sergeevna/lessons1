# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %% [markdown]
# Перечень полок, на которых находятся документы хранится в следующем виде:

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

# %% [markdown]
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# - p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# - s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# *Правильно обработайте ситуации, когда пользователь будет вводить несуществующий документ*.
# - l – list – команда, которая выведет список всех документов в формате
# **passport "2207 876234" "Василий Гупкин"**
# - as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. *Предусмотрите случай, когда пользователь добавляет полку, которая уже существует*.
# - d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. *Предусмотрите сценарий, когда пользователь вводит несуществующий документ*;
# - m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. *Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку*;
# - a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться. *Корректно обработайте ситуацию, когда пользователь будет пытаться добавить документ на несуществующую полку*.

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}
def people_doc():
    user_input=input("Ведите номер документа  ")
    l=len(documents)
    i=0
    while i<l:
        a=documents[i]
        tip_doc=a['type']
        nom_doc=a['number']
        name_doc=a['name']
        if user_input==nom_doc:
            print(name_doc)
            break
        else:
            i+=1
            if i<l2:
                pass
            else:
                print('Документа с таким номером нет в хранилище')
                
def dir_num():
    user_input=input("Ведите номер документа  ")
    l=len(documents)
    l2=len(directories)
    i=0
    while i<l2:
        a=directories[f'{i+1}']
        if user_input in a:
            print(f"Документ {user_input} находится на полке {i+1}")
            break
        else:
            i+=1
            if i<l2:
                pass
            else:
                print('Документа с таким номером нет ни на одной полке')
        
        
def list_doc():
    l=len(documents)
    print('Список документов в хранилище:')
    for i in range(0,l):
        a=documents[i]
        tip_doc=a['type']
        nom_doc=a['number']
        name_doc=a['name']
        print(f'{tip_doc} " {nom_doc}" {name_doc}')

def plus_dir():
    user_input=input("Ведите номер новой полки ")
    a=directories.keys()
    if user_input in a:
        print('Полка с таким номером уже существует')
    else:
        directories[user_input]=[]
        
def del_doc():
    user_input=input("Ведите номер документа который нужно удалить ")
    l=len(documents)
    l2=len(directories)
    i=0
    while i<l2:
        a=directories[f'{i+1}']
        if user_input in a:
            b=a.index(user_input)
            del a[b]
            break
        else:
            i+=1
            if i<l2:
                pass
            else:
                print('Документа с таким номером нет в системе')
    l=len(documents)
    i=0
    while i<l:
        a=documents[i]
        nom_doc=a['number']
        if user_input==nom_doc:
            del documents[i]
            print(f'Документ номер {user_input} удален из хранилища и с полки')
            break
        else:
            i+=1
            if i<l2:
                pass
            else:
                break
    
def move_doc():
    user_input_d=input("Ведите номер документа который нужно переместить ")
    user_input_i=input("Ведите номер полки на которую переместить ")
    l2=len(directories)
    i=0
    while i<l2:
        a=directories[f'{i+1}']
        if user_input_d in a:
            b=a.index(user_input_d)
            d=directories.keys()
            if user_input_i in d:
                del a[b]
                c=directories[f'{user_input_i}']
                c.append(f'{user_input_d}')
                print(c)
                break
            else:
                print('Вы пытались переместить документ на несуществующую полку.\
                Повторите команду с корректными данными или добавте полку в систему')
                break
        else:
            i+=1
            if i<l2:
                pass
            else:
                print('Документа с таким номером нет в системе')
    
def add_doc():
    user_input_t=input("Ведите тип документа  ")
    user_input_n=input("Ведите номер документа ")
    user_input_na=input("Ведите имя владельца ")
    l2=len(directories)
    i=0
    new_doc={'type':user_input_t , 'number':user_input_n , 'name':user_input_na}
    documents.append(new_doc)
    user_input_d=input("Ведите номер полки на которую поместить документ ")
    l2=len(directories)
    i=0
    while i<l2:
        a=directories.keys()
        if user_input_d in a:
            c=directories[f'{user_input_d}']
            c.append(f'{user_input_n}')
            break
        else:
            i+=1
            if i<l2:
                pass
            else:
                print('Вы пытались добавить документ на несуществующую полку.\
                Повторите команду с корректными данными или добавте полку в систему')
                break
       
        
def main():
    print("Для определения имени человека по номеру документа введите - p\
    Для определения номера полки на которой хранится документ введите - s \
    Для вывода списка всех документов хранящихся в отделе введите - l\
    Для добавления новой полки для хранения документов введите - as\
    Для удаления документа из каталога и соответствующей полки введите – d\
    Для перемещения документа введите - m \
    Для добавления документа в каталог и определения места его дальнейшего хранения введите - a\
    Для выхода введите - e ")
    while True:
        user_input=input("Ведите команду  ")
        if user_input=='l':
            list_doc()
        elif user_input=='p':
            people_doc()
        elif user_input=='s':
            dir_num()
        elif user_input=='as':
            plus_dir()
        elif user_input=='d':
            del_doc()
        elif user_input=='m':
            move_doc()
        elif user_input=='a':
            add_doc()
        elif user_input=='e':
            break
